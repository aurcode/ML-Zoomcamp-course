# %%
import numpy as np
import pandas as pd

# %%
print('pandas', pd.__version__)
print('numpy', np.__version__)
# Out:
# pandas 1.2.4
# numpy 1.20.1

# %%
df = pd.read_csv('./data.csv')
df[df['Make']=='BMW'].mean()
# Out:
# Year                 2014.347305
# Engine HP             326.907186
# Engine Cylinders        5.958084
# Number of Doors         3.161677
# highway MPG            29.245509
# city mpg               20.739521
# Popularity           3916.000000
# MSRP                61546.763473
# dtype: float64

# %%
len(df[df['Year']>2015]['Engine HP'].unique())
# Out:
# 218
